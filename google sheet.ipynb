# %%
pip install gspread oauth2client
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials

# %%
# use creds to create a client to in
# use creds to create a client to interact with the Google Drive API
scope =['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']

# %%
creds= ServiceAccountCredentials.from_json_keyfile_name('amitttt.json', scope)


# Find a workbook by name and open the first sheet

# %%
client = gspread.authorize(creds)

# %%
sheet = client.open('Legislators spreadsheet').sheet1

# %%
list_of_hashes = sheet.get_all_records()

# %%
list_of_hashes
# Out:
# [{'I just wrote to a spreadsheet using Python!': 1,
#   'LotFrontage': 65,
#   'LotArea': 'Blue',
#   'Alley': 'NA',
#   'MasVnrArea': 196,
#   '1stFlrSF': 856,
#   '2ndFlrSF': 854,
#   'GrLivArea': 1710,
#   'GarageType': 'Attchd',
#   'GarageArea': 548,
#   'SalePrice': 208500},
#  {'I just wrote to a spreadsheet using Python!': 2,
#   'LotFrontage': 80,
#   'LotArea': 9600,
#   'Alley': 'NA',
#   'MasVnrArea': 0,
#   '1stFlrSF': 1262,
#   '2ndFlrSF': 0,
#   'GrLivArea': 1262,
#   'GarageType': 'Attchd',
#   'GarageArea': 460,
#   'SalePrice': 181500},
#  {'I just wrote to a spreadsheet using Python!': 3,
#   'LotFrontage': 68,
#   'LotArea': 11250,
#   'Alley': 'NA',
#   'MasVnrArea': 162,
#   '1stFlrSF': 920,
#   '2ndFlrSF': 866,
#   'GrLivArea': 1786,
#   'GarageType': 'Attchd',
#   'GarageArea': 608,
#   'SalePrice': 223500},
#  {'I just wrote to a spreadsheet using Python!': 4,
#   'LotFrontage': 60,
#   'LotArea': 9550,
#   'Alley': 'NA',
#   'MasVnrArea': 0,
# ...

# %%
sheet.row_values(1)
# Out:
# ['I just wrote to a spreadsheet using Python!',
#  'LotFrontage',
#  'LotArea',
#  'Alley',
#  'MasVnrArea',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'GarageType',
#  'GarageArea',
#  'SalePrice']

# %%
sheet.col_values(5)
# Out:
# ['MasVnrArea',
#  '196',
#  '0',
#  '162',
#  '0',
#  '350',
#  '0',
#  '186',
#  '240',
#  '0',
#  '0',
#  '0',
#  '286',
#  '0',
#  '306',
#  '212',
#  '0',
#  '180',
#  '0',
#  '0',
#  '0',
#  '380',
#  '0',
#  '281',
#  '0',
#  '0',
#  '640',
#  '0',
#  '200',
#  '0',
#  '0',
#  '0',
#  '0',
#  '0',
#  '0',
#  '246',
#  '132',
#  '0',
#  '650',
#  '0',
#  '0',
#  '101',
#  '0',
#  '0',
#  '0',
#  '0',
#  '412',
#  '0',
#  '0',
#  '0',
#  '0',
#  '0',
#  '0',
#  '0',
#  '0',
#  '0',
#  '272',
#  '456',
#  '0',
#  '1031',
#  '0',
#  '0',
#  '0',
#  '178',
#  '0',
#  '573',
#  '344',
#  '287',
#  '167',
#  '0',
#  '0',
#  '1115',
#  '0',
#  '40',
#  '104',
#  '0',
#  '0',
#  '0',
#  '0',
#  '0',
#  '0',
#  '576',
#  '443',
#  '468',
#  '66',
#  '22',
#  '284',
#  '0',
#  '76',
#  '0',
#  '0',
#  '0',
#  '203',
#  '0',
#  '0',
#  '0',
#  '68',
#  '183',
#  '48',
#  '0',
#  '0',
#  '28',
#  '336',
#  '0',
#  '0',
#  '600',
#  '768',
#  '0',
#  '0',
#  '0',
#  '480',
#  '0',
#  '0',
# ...

# %%
sheet.cell(1, 1).value
# Out:
# 'I just wrote to a spreadsheet using Python!'

# %%
sheet.update_cell(2, 2, "I just wrote to a spreadsheet using Python!")
# Out:
# {'spreadsheetId': '1pgLjwXD5j2kTH6_LoTIV-wR4hmCYTbekUj22GBd4aSA',
#  'updatedRange': 'Sheet1!B2',
#  'updatedRows': 1,
#  'updatedColumns': 1,
#  'updatedCells': 1}

# %%
row = ["I'm","inserting","a","row","into","a,","Spreadsheet","with","Python"]
index = 1
sheet.insert_row(row, index)
# Out:
# {'spreadsheetId': '1pgLjwXD5j2kTH6_LoTIV-wR4hmCYTbekUj22GBd4aSA',
#  'updatedRange': 'Sheet1!A1:I1',
#  'updatedRows': 1,
#  'updatedColumns': 9,
#  'updatedCells': 9}

# %%
sheet.delete_row(1)
# Out:
# {'spreadsheetId': '1pgLjwXD5j2kTH6_LoTIV-wR4hmCYTbekUj22GBd4aSA',
#  'replies': [{}]}

# %%
sheet.row_count
# Out:
# 1461

# %%
import pprint as pp

# %%
pp.pprint(list_of_hashes)
# Out:
# [{'1stFlrSF': 856,
#   '2ndFlrSF': 854,
#   'Alley': 'NA',
#   'GarageArea': 548,
#   'GarageType': 'Attchd',
#   'GrLivArea': 1710,
#   'Id': 1,
#   'LotArea': 8450,
#   'LotFrontage': 65,
#   'MasVnrArea': 196,
#   'SalePrice': 208500},
#  {'1stFlrSF': 1262,
#   '2ndFlrSF': 0,
#   'Alley': 'NA',
#   'GarageArea': 460,
#   'GarageType': 'Attchd',
#   'GrLivArea': 1262,
#   'Id': 2,
#   'LotArea': 9600,
#   'LotFrontage': 80,
#   'MasVnrArea': 0,
#   'SalePrice': 181500},
#  {'1stFlrSF': 920,
#   '2ndFlrSF': 866,
#   'Alley': 'NA',
#   'GarageArea': 608,
#   'GarageType': 'Attchd',
#   'GrLivArea': 1786,
#   'Id': 3,
#   'LotArea': 11250,
#   'LotFrontage': 68,
#   'MasVnrArea': 162,
#   'SalePrice': 223500},
#  {'1stFlrSF': 961,
#   '2ndFlrSF': 756,
#   'Alley': 'NA',
#   'GarageArea': 642,
#   'GarageType': 'Detchd',
#   'GrLivArea': 1717,
#   'Id': 4,
#   'LotArea': 9550,
#   'LotFrontage': 60,
#   'MasVnrArea': 0,
#   'SalePrice': 140000},
#  {'1stFlrSF': 1145,
# ...

# %%
sheet.update_cell(2, 3, 'Blue')
# Out:
# {'spreadsheetId': '1pgLjwXD5j2kTH6_LoTIV-wR4hmCYTbekUj22GBd4aSA',
#  'updatedRange': 'Sheet1!C2',
#  'updatedRows': 1,
#  'updatedColumns': 1,
#  'updatedCells': 1}
